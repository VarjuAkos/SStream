# %% [markdown]
# #Clone roop repo and install dependencies

# %%
# !git clone https://github.com/s0md3v/roop.git
# %cd roop
# !pip install -r requirements.txt
# Out:
# Cloning into 'roop'...
# remote: Enumerating objects: 1534, done.
# remote: Total 1534 (delta 0), reused 0 (delta 0), pack-reused 1534
# Receiving objects: 100% (1534/1534), 97.43 MiB | 27.14 MiB/s, done.
# Resolving deltas: 100% (914/914), done.
# /home/varjuakos/DeepFake/roop
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Ignoring tkinterdnd2-universal: markers 'sys_platform == "darwin" and platform_machine == "arm64"' don't match your environment
# Ignoring onnxruntime: markers 'python_version != "3.9" and sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# Ignoring onnxruntime-coreml: markers 'python_version == "3.9" and sys_platform == "darwin" and platform_machine != "arm64"' don't match your environment
# ...

# %% [markdown]
# #download model

# %%
# !wget https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx -O inswapper_128.onnx
# !mkdir models
# !mv inswapper_128.onnx ./models
# Out:
# --2024-01-05 03:39:44--  https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx
# Resolving huggingface.co (huggingface.co)... 13.32.110.77, 13.32.110.55, 13.32.110.109, ...
# Connecting to huggingface.co (huggingface.co)|13.32.110.77|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python3 run.py --target content\target\ez.mp4 --output-video-quality 80 --source content\faces\image12.png -o content\render\swapped.mp4 --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# python3: can't open file '/home/varjuakos/DeepFake/roop/roop/run.py': [Errno 2] No such file or directory

# %%
cd roop
# Out:
# /home/varjuakos/DeepFake/roop

# %%
# !python3 run.py --target content/target/josz2.mp4 --output-video-quality 80 --source content/faces/p.jpg -o content/render/jopsz2.mp4 --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/varjuakos/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/varjuakos/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/varjuakos/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /home/varjuakos/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# ...
